# %% [markdown]
# <a href="https://colab.research.google.com/github/bimardis/crawling/blob/main/Crawling_komentar_youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **CRAWLING KOMENTAR VIDEO YOUTUBE**

# %% [markdown]
# **1. Import Library**

# %%
import pandas as pd
from googleapiclient.discovery import build

# %% [markdown]
# **2. Fungsi untuk crawling komentar**

# %%
def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3', developerKey=api_key)

	# retrieve youtube video results
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()

	# iterate video response
	while video_response:

		# extracting required info
		# from each result object
		for item in video_response['items']:

			# Extracting comments ()
			published = item['snippet']['topLevelComment']['snippet']['publishedAt']
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

			replies.append([published, user, comment, likeCount])

			# counting number of reply of comment
			replycount = item['snippet']['totalReplyCount']

			# if reply is there
			if replycount>0:
				# iterate through all reply
				for reply in item['replies']['comments']:

					# Extract reply
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay']
					likeCount = reply['snippet']['likeCount']

					# Store reply is list
					#replies.append(reply)
					replies.append([published, user, repl, likeCount])

			# print comment with list of reply
			#print(comment, replies, end = '\n\n')

			# empty reply list
			#replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'],
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %% [markdown]
# **3. Jalankan Proses Crawling**

# %%
# isikan dengan api key Anda
api_key = 'AIzaSyAqbR0NPrvdecjkIK0NLP7PYMlkbpH4HIY'

# Enter video id
video_id = "RVxII4HHuRI" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2024-09-30T19:55:05Z',
#   '@tatangmulyadi-r5b',
#   'Indonesia dalam keadaan baik2 saja,Indonesia memang tidak memihak tetapi Indonesia wajib berhat-hati waspada dan lagi tidak terpancing dengan propokasi2 yg mau memancing Indonesia!!!',
#   0],
#  ['2024-09-30T18:51:13Z',
#   '@SuryaDarman-uz6hw',
#   'Baguslah 😂😂sy cuma mau cari koruptor itu yg bantai duluan karna mereka ngg di hukum mati 😂😂',
#   0],
#  ['2024-09-30T18:12:58Z',
#   '@Campmayonk',
#   'ARAB SAUDI AJA NGEBOLEHIN PESAWAT ISRAEL TERBANG DI ATAS LANGIT NYA WKWKWK',
#   0],
#  ['2024-09-30T18:07:27Z',
#   '@yuliantoyanto6956',
#   'Budaya membangun BUNKER di setiap pembangunan Rumah penduduk kurang di Indonesia khususnya dalam hal terjadi perang NUCLEAR maka penduduk akan mengalami kesusahan dalam perlindungan ketika terjadi perang',
#   0],
#  ['2024-09-30T17:49:47Z', '@arkianpratysta182', '🤲💢👍', 0],
#  ['2024-09-30T17:41:04Z',
#   '@Cahaya1818-tv1sn',
# ...

# %% [markdown]
# **4. Ubah Hasil Crawling ke Dataframe**

# %%
df = pd.DataFrame(comments, columns=['publishedAt', 'authorDisplayName', 'textDisplay', 'likeCount'])
df
# Out:
#               publishedAt   authorDisplayName  \
# 0    2024-09-30T19:55:05Z  @tatangmulyadi-r5b
# 1    2024-09-30T18:51:13Z  @SuryaDarman-uz6hw
# 2    2024-09-30T18:12:58Z         @Campmayonk
# 3    2024-09-30T18:07:27Z  @yuliantoyanto6956
# 4    2024-09-30T17:49:47Z  @arkianpratysta182
# ..                    ...                 ...
# 556  2024-09-28T12:01:35Z     @tamandunia3086
# 557  2024-09-28T12:08:56Z        @gameboy-m7i
# 558  2024-09-28T12:21:24Z        @wowokgg7280
# 559  2024-09-28T13:19:45Z     @DarsonoJatmiko
# 560  2024-09-28T15:05:09Z       @boybehel2850
#
#                                            textDisplay  likeCount
# 0    Indonesia dalam keadaan baik2 saja,Indonesia m...          0
# 1    Baguslah 😂😂sy cuma mau cari koruptor itu yg ba...          0
# 2    ARAB SAUDI AJA NGEBOLEHIN PESAWAT ISRAEL TERBA...          0
# 3    Budaya membangun BUNKER di setiap pembangunan ...          0
# 4                                                  🤲💢👍          0
# ...

# %%
jumlah_data = len(df)
print(f"Jumlah data komentar video youtube: {jumlah_data}")
# Out:
# Jumlah data komentar video youtube: 561
